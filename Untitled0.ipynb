# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/466\ Project/CSC466-Project
# Out:
# /content/drive/MyDrive/466 Project/CSC466-Project

# %%
# !git remote rm origin
# !git remote add origin https://Shubham-Sengar:fsf@github.com/John-Blodgett/CSC466-Project.git
# !git add -A
# !git commit -m "added data processing"
# Out:
# fatal: remote origin already exists.
# ^C
# On branch main
# Changes not staged for commit:
# 	modified:   Data_Processing.ipynb
#
# Untracked files:
# 	Untitled0.ipynb
#
# no changes added to commit

# %%
# !git push -u origin master
