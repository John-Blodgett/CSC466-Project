# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/466\ Project/CSC466-Project
# Out:
# /content/drive/MyDrive/466 Project/CSC466-Project

# %%
# !git remote rm origin
# !git remote add origin https://Shubham-Sengar:senggars18@github.com/John-Blodgett/CSC466-Project.git
# !git add -A
# !git commit -m "added data processing"
# Out:
# [main baa9f5a] added data processing
#  2 files changed, 2 insertions(+), 1 deletion(-)
#  create mode 100644 Untitled0.ipynb

# %%
# !git push -u origin master
# Out:
# error: src refspec master does not match any.
# error: failed to push some refs to 'https://Shubham-Sengar:fsf@github.com/John-Blodgett/CSC466-Project.git'
